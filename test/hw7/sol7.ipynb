# %% [markdown]
# # Problem: Maximum Power Transfer

# %%
import matplotlib.pyplot as plt
from matplotlib.widgets import Slider
import numpy as np

# %% [markdown]
# ## Initialization

# %%
vs = 100e-6
rs = 50

# %% [markdown]
# # Part (c)
#
# ## Function for power

# %%
def power(vs, rs, rl):
  ## Fill this part.
  return (vs**2 * rl) / (rs + rl)**2

# %% [markdown]
# ## Run the cell below to generate the plot for P_L vs R_L.

# %%
rl = np.arange(1000)  ## Try changing this value.
pl = []
for i in range((len(rl))):
  pl.append(power(vs, rs, rl[i]))
pl = np.array(pl)

plt.figure()
plt.plot(rl, pl)
plt.xlabel("$R_L$")
plt.ylabel("$P_L$")
plt.title("$P_L$ vs $R_L$")
# Out:
# Text(0.5, 1.0, '$P_L$ vs $R_L$')

# %% [markdown]
# ## Obtain the R_L that maximizes P_L and the maximum value of P_L.

# %%
rl_at_max_power = rl[np.argmax(pl)] ## Fill this part. Hint: use function like np.argmax.
max_power = np.max(pl) ## Fill this part. Hint: use function like np.max.

print("Load Resistance at maximum power (in Ohms): ", end="")
print(rl_at_max_power)
print("Maximum power (in W): ", end="")
print(np.round(max_power, 11))
# Out:
# Load Resistance at maximum power (in Ohms): 50
# Maximum power (in W): 5e-11
